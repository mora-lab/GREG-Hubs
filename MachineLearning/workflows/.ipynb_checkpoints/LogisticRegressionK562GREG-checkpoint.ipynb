# %% [markdown]
# # Logistic Regression Pipeline for K562 (GREG)

# %% [markdown]
# This notebook assesses variaegated implementations of the logistic regression models for the data dervied from the K562 cell-line in GREG.

# %% [markdown]
# ## Contents

# %% [markdown]
# * [1. Loading Packages](#link1)
# * [2. Loading Data](#link2)
# * [3. Building Model](#link3)
# * [4. Dealing with the *Paradox* of Accuracy ](#link4)
#     * [4.1 Problem of Class Imbalance](#link5)
#         * [4.1.1 Oversampling of minority class](#link6)
#         * [4.1.2 Undersampling of minority class](#link7)
#         * [4.1.3 SMOTE](#link8)
#         * [4.1.4 Both over- and under-sampling](#link9)
# * [5. Ratifying the *Pareto's Principle*](#link10)
#     * [5.1 SMOTE data](#link11)
# * [6. Visualizing Predictions](#link12)
# * [7. Session Information](#link13)

# %% [markdown]
# ### <a id=link1>1. Loading Packages </a>

# %%
requiredPackages <- c("glmnet", "rms", "caret", "e1071", "ROSE", "DMwR", "BiocManager", "ROCR")
newPackages <- requiredPackages[!(requiredPackages %in% installed.packages()[,"Package"])]
if(length(newPackages)) install.packages(newPackages, dependencies = TRUE)

library(glmnet)
library(rms)
library(caret)
library(e1071)
library(ROSE)
library(DMwR)
library(ROCR)
# Out:
# Loading required package: Matrix
#
# Loaded glmnet 4.0-2
#
# Loading required package: Hmisc
#
# Loading required package: lattice
#
# Loading required package: survival
#
# Loading required package: Formula
#
# Loading required package: ggplot2
#
#
# Attaching package: ‘Hmisc’
#
#
# The following objects are masked from ‘package:base’:
#
#     format.pval, units
#
#
# Loading required package: SparseM
#
#
# Attaching package: ‘SparseM’
#
#
# The following object is masked from ‘package:base’:
#
#     backsolve
#
#
#
# Attaching package: ‘caret’
#
#
# The following object is masked from ‘package:survival’:
#
#     cluster
#
#
#
# Attaching package: ‘e1071’
#
#
# The following object is masked from ‘package:Hmisc’:
#
#     impute
#
#
# Loaded ROSE 0.0-3
#
#
# Loading required package: grid
#
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo

# %% [markdown]
# ### <a id=link2>2. Loading Data </a>

# %%
k562gregStandard <- read.table("../data/K562forML.txt", header = TRUE) ## loading full data
k562greg <- k562gregStandard[, -c(1:3)] ## removing the first three columns for non-usage in the ML model.

# %%
head(k562greg)
# Out:
#   CTCF     EP300     H3K27me3  H3K36me3 H3K4me1   H3K4me2  H3K4me3  H3K9ac
# 1  0.00000 0.0000000 0.0000000 0.000000 0.0000000 0.000000 0.000000 0.000000
# 2  0.00000 0.0000000 0.0000000 0.000000 0.0000000 0.000000 0.000000 0.000000
# 3  0.00000 0.0000000 0.0000000 0.000000 0.0000000 0.000000 0.000000 0.000000
# 4  0.00000 0.0000000 0.0000000 0.000000 0.0000000 0.000000 0.000000 0.000000
# 5  0.00000 0.0000000 0.0000000 0.000000 0.0000000 0.000000 0.000000 0.000000
# 6 47.61676 0.0274939 0.8087214 1.045595 0.7726153 1.202883 1.627348 1.188197
#   H3K9me3 RAD21    RNA.Seq RNAPol2   RNAPol3  YY1       Class
# 1 0.00000 0.000000 0       0.0000000  0.00000 0.0000000 Non-Hub
# 2 0.00000 0.000000 0       0.0000000  0.00000 0.0000000 Non-Hub
# 3 0.00000 0.000000 0       0.0000000  0.00000 0.0000000 Non-Hub
# 4 0.00000 0.000000 0       0.0000000  0.00000 0.0000000 Non-Hub
# 5 0.00000 0.000000 0       0.0000000  0.00000 0.0000000 Non-Hub
# 6 6.28546 8.497575 0       0.1668389 20.66886 0.1562263 Non-Hub

# %%
set.seed(005)
cv.modelfit <- cv.glmnet(as.matrix(k562greg[,1:14]),
                         k562greg$Class,
                         family = "binomial",
                         type.measure = "class",
                         alpha = 1,
                         nlambda = 100)


plot(cv.modelfit)
# Out:
# plot without title

# %%
cat("There are", length(cv.modelfit$lambda),
    "lambda values in all:\n",
    cv.modelfit$lambda,
    "\n, out of which",
    min(cv.modelfit$lambda),
    "is the minimum, while",
    cv.modelfit$lambda.1se,
    "denotes the value at which the model is optimized at one standard error.")
# Out:
# There are 56 lambda values in all:
#  0.002853877 0.002600347 0.002369339 0.002158853 0.001967067 0.001792318 0.001633093 0.001488014 0.001355823 0.001235375 0.001125628 0.00102563 0.0009345161 0.0008514962 0.0007758517 0.0007069271 0.0006441257 0.0005869033 0.0005347645 0.0004872575 0.0004439709 0.0004045297 0.0003685924 0.0003358477 0.0003060119 0.0002788266 0.0002540564 0.0002314868 0.0002109221 0.0001921844 0.0001751113 0.0001595549 0.0001453804 0.0001324652 0.0001206974 0.000109975 0.0001002051 9.130315e-05 8.319203e-05 7.580148e-05 6.906749e-05 6.293172e-05 5.734104e-05 5.224702e-05 4.760554e-05 4.337639e-05 3.952295e-05 3.601184e-05 3.281265e-05 2.989767e-05 2.724164e-05 2.482157e-05 2.261649e-05 2.06073e-05 1.877661e-05 1.710854e-05
# , out of which 1.710854e-05 is the minimum, while 0.002853877 denotes the value at which the model is optimized at one standard error.

# %% [markdown]
# ### <a id=link3>3. Building Model </a>

# %%
set.seed(2)
modelfit <- glmnet(as.matrix(k562greg[,1:14]),
                   k562greg$Class,
                   family = "binomial",
                   alpha = 1,
                   lambda = cv.modelfit$lambda)

# Listing non-zero coefficients
print(modelfit$beta[,1])
# Out:
#          CTCF         EP300      H3K27me3      H3K36me3       H3K4me1
#  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#       H3K4me2       H3K4me3        H3K9ac       H3K9me3         RAD21
#  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#       RNA.Seq       RNAPol2       RNAPol3           YY1
#  0.000000e+00 -3.123273e-16  0.000000e+00  0.000000e+00

# %%
coef(modelfit)[,1]
predict(modelfit, type="coef")
# Out:
#   (Intercept)          CTCF         EP300      H3K27me3      H3K36me3
#  6.021623e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#       H3K4me1       H3K4me2       H3K4me3        H3K9ac       H3K9me3
#  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
#         RAD21       RNA.Seq       RNAPol2       RNAPol3           YY1
#  0.000000e+00  0.000000e+00 -3.123273e-16  0.000000e+00  0.000000e+00
#    [[ suppressing 56 column names ‘s0’, ‘s1’, ‘s2’ ... ]]
# 15 x 56 sparse Matrix of class "dgCMatrix"
#
# (Intercept)  6.021623e+00  6.03775478  6.04620156  6.05226594  6.05720879
# CTCF         .             .           .           .           .
# EP300        .             .           .           .           .
# H3K27me3     .             .           .           .           .
# H3K36me3     .             .           .           .           .
# H3K4me1      .             .           .           .           .
# H3K4me2      .             .           .           .           .
# H3K4me3      .             .           .           .           .
# H3K9ac       .             .           .           .           .
# H3K9me3      .             .           .           .           .
# RAD21        .             .           .           .           .
# RNA.Seq      .             .           .           .           .
# RNAPol2     -3.123273e-16 -0.02055163 -0.02838924 -0.03300293 -0.03628834
# RNAPol3      .             .           .           .           .
# YY1          .             .           .           .           .
#
# (Intercept)  6.06146164  6.06521564  6.06857310  6.072264947  6.075760375
# CTCF         .           .           .           .            .
# EP300        .           .           .           .            .
# H3K27me3     .           .           .           .            .
# H3K36me3     .           .           .           .            .
# H3K4me1      .           .           .           .            .
# H3K4me2      .           .           .           .            .
# H3K4me3      .           .           .           .            .
# H3K9ac       .           .           .          -0.001611546 -0.003389248
# H3K9me3      .           .           .           .            .
# RAD21        .           .           .           .            .
# RNA.Seq      .           .           .           .            .
# RNAPol2     -0.03884952 -0.04094447 -0.04270708 -0.043448661 -0.043881016
# RNAPol3      .           .           .           .            .
# YY1          .           .           .           .            .
#
# (Intercept)  6.078617778  6.086831142  6.092915407  6.097622930  6.1017596702
# CTCF         .            .            .            .            .
# EP300        .           -0.009408802 -0.015659323 -0.019962498 -0.0234058750
# H3K27me3     .            .            .            .            .
# H3K36me3     .            .            .            .            .
# H3K4me1      .            .            .            .           -0.0002703771
# H3K4me2      .            .            .            .            .
# H3K4me3      .            .            .            .            .
# H3K9ac      -0.004219739 -0.004416958 -0.004605859 -0.004811243 -0.0048635229
# H3K9me3      .            .            .            .            .
# RAD21        .            .            .            .            .
# RNA.Seq      .            .            .            .            .
# RNAPol2     -0.044599874 -0.044521555 -0.044620857 -0.044806169 -0.0450602801
# RNAPol3      .            .            .            .            .
# YY1          .            .            .            .            .
#
# (Intercept)  6.106264332  6.110779470  6.117610498  6.126519635  6.134017401
# CTCF         .            .            .            .            .
# EP300       -0.026282013 -0.028717510 -0.033240457 -0.040031316 -0.045379249
# H3K27me3     .            .            .            .            .
# H3K36me3     .            .            .            .            .
# H3K4me1     -0.002338693 -0.005079008 -0.009888916 -0.016324650 -0.021628030
# H3K4me2      .            .            .            .            .
# H3K4me3      .            .            .            .            .
# H3K9ac      -0.003960419 -0.002872783 -0.002455373 -0.002601455 -0.002850697
# H3K9me3      .            .            .            .            .
# RAD21        .            .            0.001119464  0.003622647  0.005785444
# RNA.Seq      .            .            .            .            .
# RNAPol2     -0.045703286 -0.046391254 -0.046397688 -0.045784987 -0.045255210
# RNAPol3      .            .            .            .            .
# YY1          .            .            .            .            .
#
# (Intercept)  6.140194339  6.145493446  6.150020588  6.153905270  6.157276965
# CTCF         .            .            .            .            .
# EP300       -0.049454358 -0.052675880 -0.055164965 -0.057034174 -0.058347049
# H3K27me3     .            .            .            .            .
# H3K36me3     .            .            .            .            .
# H3K4me1     -0.025960261 -0.029695383 -0.032954016 -0.035873561 -0.038616714
# H3K4me2      .            .            .            .            .
# H3K4me3      .            .            .            .            .
# H3K9ac      -0.003103225 -0.003401790 -0.003729615 -0.004083028 -0.004477527
# H3K9me3      .            .            .            .            .
# RAD21        0.007614861  0.009242009  0.010704414  0.012049839  0.013342243
# RNA.Seq      .            .            .            .            .
# RNAPol2     -0.044851699 -0.044497594 -0.044190659 -0.043919822 -0.043666411
# RNAPol3      .            .            .            .            .
# YY1          .            .            .            .            .
#
# (Intercept)  6.160128772  6.162566645  6.16461597  6.166341e+00  6.1678761580
# CTCF         .            .            .           .             0.0001191050
# EP300       -0.059126686 -0.059371554 -0.05911491 -5.846321e-02 -0.0571476431
# H3K27me3     .            .            .           .             .
# H3K36me3     .            .            .           .             .
# H3K4me1     -0.041182858 -0.043739667 -0.04629698 -4.882755e-02 -0.0516230878
# H3K4me2      .            .            .           .             .
# H3K4me3      .            .            .           .             .
# H3K9ac      -0.004894018 -0.005364183 -0.00588063 -6.421809e-03 -0.0069886418
# H3K9me3      .            .            .           .             .
# RAD21        0.014580113  0.015834733  0.01710761  1.839305e-02  0.0200959537
# RNA.Seq      .            .            .           .             .
# RNAPol2     -0.043441857 -0.043223861 -0.04301465 -4.281741e-02 -0.0426458896
# RNAPol3      .            .            .          -2.191383e-05 -0.0006137131
# YY1          .            .            .           .             .
#
# (Intercept)  6.1692156437  6.170411577  6.171270e+00  6.171674479  6.1717388663
# CTCF         0.0006994091  0.001389492  2.070906e-03  0.002786425  0.0033074157
# EP300       -0.0562035552 -0.055160798 -5.440334e-02 -0.053804428 -0.0534409222
# H3K27me3     .             .            .             .            .
# H3K36me3     .             .            .             .            .
# H3K4me1     -0.0539399107 -0.056215361 -5.814691e-02 -0.059971603 -0.0613554585
# H3K4me2      .             .            .             .            .
# H3K4me3      .             .            .             .            .
# H3K9ac      -0.0075411932 -0.008061284 -8.545438e-03 -0.009101299 -0.0096088411
# H3K9me3      .             .           -7.324497e-05 -0.000608554 -0.0008913757
# RAD21        0.0211719983  0.022001126  2.264965e-02  0.023219651  0.0237381617
# RNA.Seq      .             .            .             .            .
# RNAPol2     -0.0424848618 -0.042352129 -4.225581e-02 -0.042199621 -0.0421465467
# RNAPol3     -0.0010175611 -0.001283459 -1.493369e-03 -0.001654086 -0.0017933727
# YY1          .             .            4.893082e-04  0.002190117  0.0039118400
#
# (Intercept)  6.171549931  6.171259687  6.170748e+00  6.1702124525  6.1696671698
# CTCF         0.003847281  0.004326062  4.879833e-03  0.0053046506  0.0055529951
# EP300       -0.052817426 -0.052242762 -5.142130e-02 -0.0504510283 -0.0495420792
# H3K27me3     .            .            .             .             .
# H3K36me3     .            .            .             .             .
# H3K4me1     -0.062906174 -0.064351567 -6.609191e-02 -0.0683117052 -0.0703586168
# H3K4me2      .            .            9.737217e-04  0.0031527058  0.0051436325
# H3K4me3      .            .            .             .             .
# H3K9ac      -0.010188448 -0.010687740 -1.196236e-02 -0.0140499767 -0.0159469024
# H3K9me3     -0.001072944 -0.001204597 -1.345746e-03 -0.0014962378 -0.0016081228
# RAD21        0.024303048  0.024816057  2.543892e-02  0.0263342142  0.0272453737
# RNA.Seq      .            .            8.507335e-06  0.0001222936  0.0002423078
# RNAPol2     -0.042090116 -0.042069767 -4.209365e-02 -0.0422010561 -0.0423029362
# RNAPol3     -0.001906672 -0.002003686 -2.103039e-03 -0.0022103385 -0.0023037529
# YY1          0.005815697  0.007743046  9.583890e-03  0.0111198334  0.0126278924
#
# (Intercept)  6.1693503295  6.1692020537  6.1693854517  6.1698172886
# CTCF         0.0057054681  0.0059502057  0.0062609025  0.0066383089
# EP300       -0.0487561078 -0.0484311848 -0.0481630033 -0.0480286275
# H3K27me3     .            -0.0001209466 -0.0008764472 -0.0023436335
# H3K36me3    -0.0004751068 -0.0014238490 -0.0028769532 -0.0042643200
# H3K4me1     -0.0722947151 -0.0734082240 -0.0744738221 -0.0754353086
# H3K4me2      0.0069473356  0.0083121026  0.0096427987  0.0107720281
# H3K4me3      .             .             .             .
# H3K9ac      -0.0176319186 -0.0188515129 -0.0200043731 -0.0209342088
# H3K9me3     -0.0016615002 -0.0016519083 -0.0015506328 -0.0013882332
# RAD21        0.0283977579  0.0294370476  0.0310584712  0.0329492118
# RNA.Seq      0.0003727616  0.0005106573  0.0006573358  0.0008026021
# RNAPol2     -0.0423855299 -0.0424937469 -0.0426041559 -0.0427330717
# RNAPol3     -0.0023856018 -0.0024557291 -0.0025208869 -0.0025794911
# YY1          0.0140519685  0.0152238545  0.0162954931  0.0172595489
#
# (Intercept)  6.1702673847  6.170649564  6.1709516374  6.171219996  6.1714360308
# CTCF         0.0071149273  0.007563031  0.0079814086  0.008383358  0.0087505369
# EP300       -0.0478528716 -0.047751638 -0.0476519446 -0.047536150 -0.0474214522
# H3K27me3    -0.0042521240 -0.006134468 -0.0078719149 -0.009560921 -0.0111145794
# H3K36me3    -0.0052352309 -0.005818713 -0.0062085540 -0.006509063 -0.0067302240
# H3K4me1     -0.0764589368 -0.077349776 -0.0781720149 -0.078960755 -0.0796833785
# H3K4me2      0.0118259952  0.012764003  0.0136260458  0.014444936  0.0151997430
# H3K4me3      .             .            .             .            .
# H3K9ac      -0.0217882292 -0.022513432 -0.0231779380 -0.023812142 -0.0244016339
# H3K9me3     -0.0012081558 -0.001051602 -0.0009150482 -0.000784540 -0.0006682776
# RAD21        0.0348149297  0.036393016  0.0377617054  0.039046493  0.0402003290
# RNA.Seq      0.0009394656  0.001066158  0.0011856732  0.001299124  0.0014064039
# RNAPol2     -0.0428811019 -0.043036623 -0.0431846863 -0.043324984 -0.0434539648
# RNAPol3     -0.0026340146 -0.002683364 -0.0027281377 -0.002769373 -0.0028067986
# YY1          0.0181661964  0.018963520  0.0197024033  0.020394905  0.0210435731
#
# (Intercept)  6.1716476804  6.1718614068  6.1721043328  6.1723374983
# CTCF         0.0090975397  0.0093457047  0.0096093040  0.0098536075
# EP300       -0.0472988228 -0.0472993013 -0.0472223213 -0.0471360570
# H3K27me3    -0.0126645042 -0.0140085124 -0.0154982183 -0.0169918997
# H3K36me3    -0.0069299654 -0.0071590356 -0.0074506858 -0.0077078395
# H3K4me1     -0.0803713509 -0.0808470250 -0.0813891632 -0.0819042649
# H3K4me2      0.0159168331  0.0165021689  0.0170912755  0.0176454043
# H3K4me3      .             .             .             .
# H3K9ac      -0.0249660431 -0.0254003878 -0.0258655395 -0.0263105763
# H3K9me3     -0.0005514874 -0.0004526083 -0.0003312756 -0.0002107897
# RAD21        0.0413392597  0.0423388458  0.0434873006  0.0446223720
# RNA.Seq      0.0015081149  0.0016047082  0.0016979881  0.0017854523
# RNAPol2     -0.0435744427 -0.0436831471 -0.0437817980 -0.0438728017
# RNAPol3     -0.0028413504 -0.0028712872 -0.0028996711 -0.0029258146
# YY1          0.0216551399  0.0221755477  0.0227106227  0.0232213361
#
# (Intercept)  6.172565e+00  6.172349e+00  6.172244e+00
# CTCF         1.007061e-02  1.039385e-02  1.068900e-02
# EP300       -4.705125e-02 -4.661529e-02 -4.639123e-02
# H3K27me3    -1.848176e-02 -1.932348e-02 -2.008817e-02
# H3K36me3    -7.938457e-03 -7.584035e-03 -7.364702e-03
# H3K4me1     -8.238200e-02 -8.316123e-02 -8.369581e-02
# H3K4me2      1.816000e-02  1.875736e-02  1.928830e-02
# H3K4me3      .             .             .
# H3K9ac      -2.672961e-02 -2.732975e-02 -2.780611e-02
# H3K9me3     -9.169311e-05 -6.183774e-05 -3.281998e-05
# RAD21        4.574440e-02  4.622757e-02  4.663430e-02
# RNA.Seq      1.867244e-03  1.934955e-03  1.997430e-03
# RNAPol2     -4.395614e-02 -4.401935e-02 -4.408718e-02
# RNAPol3     -2.949746e-03 -2.972552e-03 -2.993501e-03
# YY1          2.370742e-02  2.431118e-02  2.475295e-02

# %%
set.seed(5) # for reproducibility of results.
k562greg$Class <- as.numeric(as.factor(k562greg$Class))-1
part <- sample(2, nrow(k562greg),
               replace = TRUE,
               prob = c(0.7,0.3))
train <- k562greg[part==1,]
test <- k562greg[part==2,]
cat("So, now we have",
    nrow(train),
    "training rows and",
    nrow(test),
    "testing rows")

k562model <- glm(formula = Class ~ .,
               data = train,
               family = "binomial")
summary(k562model)
# Out:
# So, now we have 1064061 training rows and 455449 testing rows
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Call:
# glm(formula = Class ~ ., family = "binomial", data = train)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -3.9458   0.0636   0.0648   0.0675   2.6203
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept)  6.203288   0.024847 249.656  < 2e-16 ***
# CTCF         0.001679   0.009982   0.168 0.866449
# EP300       -0.043000   0.011953  -3.597 0.000322 ***
# H3K27me3    -0.100968   0.019449  -5.191 2.09e-07 ***
# H3K36me3    -0.033262   0.016424  -2.025 0.042850 *
# H3K4me1     -0.087436   0.009969  -8.771  < 2e-16 ***
# H3K4me2      0.017110   0.012686   1.349 0.177404
# H3K4me3      0.019295   0.018290   1.055 0.291451
# H3K9ac      -0.042372   0.007995  -5.300 1.16e-07 ***
# H3K9me3      0.011303   0.007914   1.428 0.153195
# RAD21        0.115301   0.017095   6.745 1.53e-11 ***
# RNA.Seq      0.003138   0.002339   1.342 0.179676
# RNAPol2     -0.045618   0.002731 -16.701  < 2e-16 ***
# RNAPol3     -0.002752   0.001010  -2.724 0.006451 **
# YY1          0.050201   0.016676   3.010 0.002609 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 35588  on 1064060  degrees of freedom
# Residual deviance: 34583  on 1064046  degrees of freedom
# AIC: 34613
#
# Number of Fisher Scoring iterations: 11

# %%
vif(k562model)
# Out:
#       CTCF      EP300   H3K27me3   H3K36me3    H3K4me1    H3K4me2    H3K4me3
#  36.864211   2.580361 105.452483  63.121914  11.920563  36.911295 113.796343
#     H3K9ac    H3K9me3      RAD21    RNA.Seq    RNAPol2    RNAPol3        YY1
#  24.629977   1.381496 209.098184   1.113516   2.833112   1.402665   1.972098

# %% [markdown]
# <b>CTCF</b>, <b>H3K4me2</b>, and <b>H3K4me3</b> are the variables with no statistical significance, and high variance inflation factor value. We shall omit them and re-evaluate the model.

# %%
k562model1 <- glm(formula = Class ~ EP300 + H3K27me3 + H3K36me3 + H3K4me1 + H3K9ac + H3K9me3 + RAD21 + RNA.Seq + RNAPol2 + RNAPol3 + YY1,
               data = train,
               family = "binomial")
summary(k562model1)
# Out:
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Call:
# glm(formula = Class ~ EP300 + H3K27me3 + H3K36me3 + H3K4me1 +
#     H3K9ac + H3K9me3 + RAD21 + RNA.Seq + RNAPol2 + RNAPol3 +
#     YY1, family = "binomial", data = train)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -3.9287   0.0635   0.0648   0.0673   2.5711
#
# Coefficients:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept)  6.2066163  0.0247130 251.147  < 2e-16 ***
# EP300       -0.0529261  0.0115831  -4.569 4.89e-06 ***
# H3K27me3    -0.0977202  0.0189834  -5.148 2.64e-07 ***
# H3K36me3    -0.0353079  0.0156626  -2.254   0.0242 *
# H3K4me1     -0.0750311  0.0087559  -8.569  < 2e-16 ***
# H3K9ac      -0.0161967  0.0038759  -4.179 2.93e-05 ***
# H3K9me3      0.0117655  0.0059362   1.982   0.0475 *
# RAD21        0.1147246  0.0134702   8.517  < 2e-16 ***
# RNA.Seq      0.0034010  0.0023779   1.430   0.1526
# RNAPol2     -0.0449132  0.0025992 -17.280  < 2e-16 ***
# RNAPol3     -0.0021496  0.0009983  -2.153   0.0313 *
# YY1          0.0523897  0.0166005   3.156   0.0016 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 35588  on 1064060  degrees of freedom
# Residual deviance: 34600  on 1064049  degrees of freedom
# AIC: 34624
#
# Number of Fisher Scoring iterations: 10

# %%
vif(k562model1)
# Out:
#      EP300   H3K27me3   H3K36me3    H3K4me1     H3K9ac    H3K9me3      RAD21
#   2.429824  92.653328  53.090126   8.560988   5.778671   1.363264 118.945508
#    RNA.Seq    RNAPol2    RNAPol3        YY1
#   1.105743   2.566086   1.337723   1.955944

# %%
yTrain <- predict(k562model1, train, type = "response")
head(yTrain)
# Out:
#         1         2         4         5         7        10
# 0.9979880 0.9979880 0.9979880 0.9979880 0.9973583 0.9980094

# %%
head(train)
# Out:
#    CTCF     EP300 H3K27me3  H3K36me3 H3K4me1   H3K4me2   H3K4me3   H3K9ac
# 1  0.000000 0     0.0000000 0.000000 0.0000000 0.0000000 0.0000000 0.0000000
# 2  0.000000 0     0.0000000 0.000000 0.0000000 0.0000000 0.0000000 0.0000000
# 4  0.000000 0     0.0000000 0.000000 0.0000000 0.0000000 0.0000000 0.0000000
# 5  0.000000 0     0.0000000 0.000000 0.0000000 0.0000000 0.0000000 0.0000000
# 7  1.846856 0     0.9300297 2.533556 3.3112083 1.6483952 0.8950416 1.4451047
# 10 1.084024 0     0.5661050 3.217214 0.8461977 0.5791659 0.7323068 0.6743822
#    H3K9me3  RAD21     RNA.Seq     RNAPol2 RNAPol3   YY1 Class
# 1  0.000000 0.0000000  0.00000000 0       0.0000000 0   1
# 2  0.000000 0.0000000  0.00000000 0       0.0000000 0   1
# 4  0.000000 0.0000000  0.00000000 0       0.0000000 0   1
# 5  0.000000 0.0000000  0.00000000 0       0.0000000 0   1
# 7  4.858491 1.0692313  0.05683756 0       0.3636749 0   1
# 10 1.223117 0.9004053 40.46833918 0       0.6061248 0   1

# %%
source("modelPerformance.R")
modelPerformance(k562model1, train, train$Class)
# Out:
# The confusion matrix is
#          Actual
# Predicted       0       1
#         0      13      24
#         1    2514 1061510
# The misclassification error of the model is 0.2385202 %
# The sensitivity of the model is 0.514444 %
# The specificity of the model is 99.99774 %
# The area under curve is 0.5025609
# Warning message in if (class(model) %in% c("glm", "lm")) {:
# “the condition has length > 1 and only the first element will be used”
# The statistical significance for the model is 1
# The confidence level for the model is 0 %
# Plot with title “ROC Curve”

# %%
source("modelPerformance.R")
modelPerformance(k562model1, test, test$Class)
# Out:
# The confusion matrix is
#          Actual
# Predicted      0      1
#         0      6      9
#         1   1144 454290
# The misclassification error of the model is 0.2531568 %
# The sensitivity of the model is 0.5217391 %
# The specificity of the model is 99.99802 %
# The area under curve is 0.5025988
# Warning message in if (class(model) %in% c("glm", "lm")) {:
# “the condition has length > 1 and only the first element will be used”
# The statistical significance for the model is 1
# The confidence level for the model is 0 %
# Plot with title “ROC Curve”

# %% [markdown]
# We can clearly observe that the model has **zero sensitivity** and **high specificity**. It means that the model is highly biased towards the non-hubs and that solely accounts for the data imbalance.

# %% [markdown]
# ### <a id=link4>4. Dealing with the *Paradox* of Accuracy  </a>

# %% [markdown]
# The model is highly accurate in predicting the non-hubs individually. Since the data carries significant imbalance in the classes (non-hubs are far more in number than the hubs), the prediction for the hubs might not be well suited. We need to extend the analysis for a "balanced" data. But before we delve further, let us calculate the sensitivity and specificity parameters to check how well the model is able to identify positive class labels (0: hubs).

# %% [markdown]
# This is clearly not what we want.

# %% [markdown]
# ####  <a id=link5>4.1 Problem of Class Imbalance </a>

# %% [markdown]
# The problem of class imbalance presents a warranting scenario for data normalization in terms of class proportions. Two simple strategies to mitigate this problem are oversampling and undersampling.

# %% [markdown]
# #####  <a id=link5> 4.1.1 Oversampling of minority class </a>

# %%
table(k562greg$Class)
# Out:
#       0       1
#    3677 1515833

# %% [markdown]
# We can articulate that the hubs(class marked with '0') are way less than the non-hubs. To scale them in proportion to the non-hubs, we can choose to oversample their instances. This is carried out by randomly choosing their exisiting data points and repeating to match a specified number. The package ***ROSE*** comes in handy here. The details about the package could be found [here](https://www.rdocumentation.org/packages/ROSE/versions/0.0-3).

# %%
overTrain <- ovun.sample(Class ~., data = train, method = "over", N = 1515833)$data

# %%
table(overTrain$Class)
# Out:
#       0       1
#  454299 1061534

# %% [markdown]
# Still better. Let's run the model again to see if there is any improvement in the performance.

# %%
k562modelOver <- glm(formula = Class ~ .,
               data = overTrain,
               family = "binomial")
summary(k562modelOver)
# Out:
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Call:
# glm(formula = Class ~ ., family = "binomial", data = overTrain)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.0485  -1.1886   0.6881   0.7904   8.4904
#
# Coefficients:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept)  1.5842619  0.0036074  439.17  < 2e-16 ***
# CTCF         0.0219341  0.0014770   14.85  < 2e-16 ***
# EP300        0.0628583  0.0023536   26.71  < 2e-16 ***
# H3K27me3    -0.3838731  0.0026354 -145.66  < 2e-16 ***
# H3K36me3    -0.2072996  0.0021884  -94.73  < 2e-16 ***
# H3K4me1     -0.1743958  0.0016646 -104.77  < 2e-16 ***
# H3K4me2      0.1417790  0.0028300   50.10  < 2e-16 ***
# H3K4me3     -0.0470963  0.0033222  -14.18  < 2e-16 ***
# H3K9ac      -0.1256631  0.0019766  -63.58  < 2e-16 ***
# H3K9me3     -0.0085739  0.0015149   -5.66 1.52e-08 ***
# RAD21       -0.1302143  0.0037281  -34.93  < 2e-16 ***
# RNA.Seq      0.0051830  0.0002902   17.86  < 2e-16 ***
# RNAPol2     -0.0307730  0.0007080  -43.47  < 2e-16 ***
# RNAPol3     -0.0104946  0.0002974  -35.29  < 2e-16 ***
# YY1          0.0325265  0.0025948   12.54  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 1851172  on 1515832  degrees of freedom
# Residual deviance: 1704421  on 1515818  degrees of freedom
# AIC: 1704451
#
# Number of Fisher Scoring iterations: 6

# %%
modelPerformance(k562modelOver, test, test$Class)
# Out:
# The confusion matrix is
#          Actual
# Predicted      0      1
#         0    184  16338
#         1    966 437961
# The misclassification error of the model is 3.799328 %
# The sensitivity of the model is 16 %
# The specificity of the model is 96.40369 %
# The area under curve is 0.5620185
# Warning message in if (class(model) %in% c("glm", "lm")) {:
# “the condition has length > 1 and only the first element will be used”
# The statistical significance for the model is 1
# The confidence level for the model is 0 %
# Plot with title “ROC Curve”

# %% [markdown]
# This is better than before but still not good enough. Maybe we can try the other approach.

# %% [markdown]
# ##### <a id=link5> 4.1.2 Undersampling of majority class  </a>

# %% [markdown]
# Contrary to what we did above, we shall now scale down the random data points from the majority class and see if the model performs any better.

# %%
underTrain <- ovun.sample(Class ~., data = train, method = "under", N= 5000)$data
table(underTrain$Class)
# Out:
#    0    1
# 2527 2473

# %%
k562modelUnder <- glm(formula = Class ~ .,
               data = underTrain,
               family = "binomial")
summary(k562modelUnder)
# Out:
# Call:
# glm(formula = Class ~ ., family = "binomial", data = underTrain)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.6442  -1.1619  -0.0807   1.0394   6.4547
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept)  0.809841   0.060634  13.356  < 2e-16 ***
# CTCF        -0.036067   0.027211  -1.325 0.185021
# EP300        0.029028   0.047369   0.613 0.539999
# H3K27me3    -0.479882   0.047037 -10.202  < 2e-16 ***
# H3K36me3    -0.245681   0.039811  -6.171 6.78e-10 ***
# H3K4me1     -0.179902   0.030774  -5.846 5.04e-09 ***
# H3K4me2      0.123807   0.052511   2.358 0.018387 *
# H3K4me3     -0.024646   0.061669  -0.400 0.689416
# H3K9ac      -0.124292   0.035936  -3.459 0.000543 ***
# H3K9me3     -0.068058   0.026004  -2.617 0.008865 **
# RAD21        0.039125   0.060634   0.645 0.518761
# RNA.Seq      0.012879   0.005265   2.446 0.014446 *
# RNAPol2     -0.028892   0.013842  -2.087 0.036868 *
# RNAPol3     -0.010464   0.004797  -2.181 0.029148 *
# YY1          0.029340   0.055042   0.533 0.594002
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 6930.9  on 4999  degrees of freedom
# Residual deviance: 6370.3  on 4985  degrees of freedom
# AIC: 6400.3
#
# Number of Fisher Scoring iterations: 6

# %%
vif(k562modelUnder)
# Out:
#      CTCF     EP300  H3K27me3  H3K36me3   H3K4me1   H3K4me2   H3K4me3    H3K9ac
#  2.714556  2.145456  1.191893  1.530538  1.994700 24.062983 22.152875  9.701228
#   H3K9me3     RAD21   RNA.Seq   RNAPol2   RNAPol3       YY1
#  1.145888  2.795143  1.220522  2.378733  1.258803  1.705298

# %% [markdown]
# We can chuck-off **H3K4me3** for having high values for *p* and VIF.

# %%
k562modelUnder1 <- glm(formula = Class ~ CTCF + EP300 + H3K27me3 + H3K36me3 + H3K4me1 + H3K4me2 + H3K9ac + H3K9me3 + RAD21 + RNA.Seq + RNAPol2 + RNAPol3 + YY1,
               data = underTrain,
               family = "binomial")
summary(k562modelUnder1)
# Out:
# Call:
# glm(formula = Class ~ CTCF + EP300 + H3K27me3 + H3K36me3 + H3K4me1 +
#     H3K4me2 + H3K9ac + H3K9me3 + RAD21 + RNA.Seq + RNAPol2 +
#     RNAPol3 + YY1, family = "binomial", data = underTrain)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.6200  -1.1611  -0.0766   1.0401   6.4295
#
# Coefficients:
#              Estimate Std. Error z value Pr(>|z|)
# (Intercept)  0.807549   0.060351  13.381  < 2e-16 ***
# CTCF        -0.035023   0.027067  -1.294 0.195687
# EP300        0.028189   0.047573   0.593 0.553487
# H3K27me3    -0.480111   0.047026 -10.210  < 2e-16 ***
# H3K36me3    -0.248191   0.039318  -6.312 2.75e-10 ***
# H3K4me1     -0.176936   0.029928  -5.912 3.38e-09 ***
# H3K4me2      0.107195   0.031883   3.362 0.000773 ***
# H3K9ac      -0.128759   0.034390  -3.744 0.000181 ***
# H3K9me3     -0.068712   0.025953  -2.648 0.008108 **
# RAD21        0.037555   0.060519   0.621 0.534898
# RNA.Seq      0.012930   0.005262   2.457 0.014005 *
# RNAPol2     -0.028242   0.013682  -2.064 0.038998 *
# RNAPol3     -0.010799   0.004695  -2.300 0.021444 *
# YY1          0.030058   0.054933   0.547 0.584262
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 6930.9  on 4999  degrees of freedom
# Residual deviance: 6370.5  on 4986  degrees of freedom
# AIC: 6398.5
#
# Number of Fisher Scoring iterations: 6

# %%
vif(k562modelUnder1)
# Out:
#     CTCF    EP300 H3K27me3 H3K36me3  H3K4me1  H3K4me2   H3K9ac  H3K9me3
# 2.688168 2.136008 1.191195 1.493158 1.879495 8.879064 8.801884 1.142421
#    RAD21  RNA.Seq  RNAPol2  RNAPol3      YY1
# 2.782959 1.219571 2.325611 1.232561 1.705090

# %%
modelPerformance(k562modelUnder1, "lr", test, Class)
# Out:
# The confusion matrix is
#          Actual
# Predicted      0      1
#         0    611 121037
#         1    539 333262
# The accuracy of the model is 73.30634 %
# The misclassification error of the model is 26.69366 %
# The sensitivity of the model is 53.13043 %
# The specificity of the model is 73.35741 %
# The area under curve is 0.6324392
# The statistical significance for the model is 2.108651e-111
# The confidence level for the model is 100 %
# Plot with title “ROC Curve”

# %% [markdown]
# This case is somewhat balanced, not only in terms of respective data points but also sensivitiy and specificity of the classifier.

# %% [markdown]
# ##### <a id=link8> 4.1.3 SMOTE  </a>

# %% [markdown]
# The sampling techniques are straighforward, but could possibly engender a classifier that overfits the training data and hence might not be suitable for a general application. To handle such a chance, [SMOTE](https://www3.nd.edu/~dial/publications/chawla2002smote.pdf) was introduced by Chawla et al. in 2002 and the functionality is available in R with the package *DMwR*.

# %%
table(k562greg$Class)
# Out:
#       0       1
#    3677 1515833

# %%
## Smote : Synthetic Minority Oversampling Technique
## A pre-requisite is that the class variable in the data must be of "factor" category. Let's do that conversion.

train$Class <- as.factor(train$Class)

smoteData <- SMOTE(Class ~., train, perc.over = 5000, k = 5, perc.under = 102)

table(smoteData$Class)
# Out:
#      0      1
# 128877 128877

# %% [markdown]
# Co-incidentally, same proportion of classes are engendered.

# %%
k562modelSMOTE <- glm(formula = Class ~ .,
                    data = smoteData,
                    family = "binomial")
summary(k562modelSMOTE)
# Out:
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Call:
# glm(formula = Class ~ ., family = "binomial", data = smoteData)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -1.7751  -1.1639  -0.0007   1.0330   8.4904
#
# Coefficients:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept)  0.8259214  0.0085386  96.728  < 2e-16 ***
# CTCF         0.0283384  0.0036907   7.678 1.61e-14 ***
# EP300        0.1203619  0.0065243  18.448  < 2e-16 ***
# H3K27me3    -0.4309704  0.0063618 -67.744  < 2e-16 ***
# H3K36me3    -0.2465066  0.0055350 -44.536  < 2e-16 ***
# H3K4me1     -0.2130824  0.0045418 -46.916  < 2e-16 ***
# H3K4me2      0.1921606  0.0079904  24.049  < 2e-16 ***
# H3K4me3     -0.0668958  0.0092520  -7.230 4.82e-13 ***
# H3K9ac      -0.1716255  0.0057160 -30.026  < 2e-16 ***
# H3K9me3      0.0087997  0.0035551   2.475   0.0133 *
# RAD21       -0.1774909  0.0097719 -18.163  < 2e-16 ***
# RNA.Seq      0.0080731  0.0008047  10.033  < 2e-16 ***
# RNAPol2     -0.0264095  0.0020147 -13.109  < 2e-16 ***
# RNAPol3     -0.0125669  0.0008222 -15.284  < 2e-16 ***
# YY1          0.0311079  0.0067154   4.632 3.62e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 357323  on 257753  degrees of freedom
# Residual deviance: 328154  on 257739  degrees of freedom
# AIC: 328184
#
# Number of Fisher Scoring iterations: 6

# %%
vif(k562modelSMOTE)
# Out:
#      CTCF     EP300  H3K27me3  H3K36me3   H3K4me1   H3K4me2   H3K4me3    H3K9ac
#  2.494493  2.532097  1.173734  1.464717  2.205190 27.450640 23.789059 11.770095
#   H3K9me3     RAD21   RNA.Seq   RNAPol2   RNAPol3       YY1
#  1.171450  2.630726  1.144883  2.779494  1.198290  1.487713

# %% [markdown]
# All is well. Let us now examine this model with the test data.

# %%
## Load a manually curated function 'modelPerformance()' to ascertain model performance
## Trace the function definition in the parent folder

modelPerformance(k562modelSMOTE, "LR", test, Class)
# Out:
# The confusion matrix is
#          Actual
# Predicted      0      1
#         0    599 115183
#         1    551 339116
# The accuracy of the model is 74.58903 %
# The misclassification error of the model is 25.41097 %
# The sensitivity of the model is 52.08696 %
# The specificity of the model is 74.64599 %
# The area under curve is 0.6336647
# The statistical significance for the model is 0
# The confidence level for the model is 100 %
# Plot with title “ROC Curve”

# %% [markdown]
# ##### <a id=link9> 4.1.4 Both over- and under-sampling </a>

# %% [markdown]
# This model has slightly better specificity than the previous model. In tandem, we could also try yet another flavor of the *ovun.sample()* function - to have under- and over-sampling both in parallel. This could be a likely run like the SMOTE as above.

# %%
bothTrain <- ovun.sample(Class ~., data = train, method = "both", N= 1515833)$data
table(bothTrain$Class)
# Out:
#      1      0
# 757447 758386

# %%
k562modelBoth <- glm(formula = Class ~ .,
               data = bothTrain,
               family = "binomial")
summary(k562modelBoth)
# Out:
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Call:
# glm(formula = Class ~ ., family = "binomial", data = bothTrain)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -8.4904  -1.0254   0.0072   1.1565   1.7859
#
# Coefficients:
#               Estimate Std. Error  z value Pr(>|z|)
# (Intercept) -0.9194994  0.0035760 -257.134  < 2e-16 ***
# CTCF        -0.0522092  0.0015123  -34.523  < 2e-16 ***
# EP300       -0.1107075  0.0023073  -47.981  < 2e-16 ***
# H3K27me3     0.4431532  0.0026513  167.146  < 2e-16 ***
# H3K36me3     0.2547270  0.0022555  112.937  < 2e-16 ***
# H3K4me1      0.2071211  0.0018062  114.674  < 2e-16 ***
# H3K4me2     -0.1761283  0.0030215  -58.292  < 2e-16 ***
# H3K4me3      0.0585316  0.0034699   16.868  < 2e-16 ***
# H3K9ac       0.1580343  0.0021649   72.998  < 2e-16 ***
# H3K9me3      0.0063074  0.0014564    4.331 1.49e-05 ***
# RAD21        0.2843101  0.0042557   66.806  < 2e-16 ***
# RNA.Seq     -0.0063699  0.0003019  -21.100  < 2e-16 ***
# RNAPol2      0.0275932  0.0007650   36.070  < 2e-16 ***
# RNAPol3      0.0123222  0.0003469   35.519  < 2e-16 ***
# YY1         -0.0229259  0.0028408   -8.070 7.01e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 2101390  on 1515832  degrees of freedom
# Residual deviance: 1916774  on 1515818  degrees of freedom
# AIC: 1916804
#
# Number of Fisher Scoring iterations: 6

# %%
modelPerformance(k562modelBoth, test, test$Class)
# Out:
# The confusion matrix is
#          Actual
# Predicted      0      1
#         0    552 339863
#         1    598 114436
# The misclassification error of the model is 74.75283 %
# The sensitivity of the model is 48 %
# The specificity of the model is 25.18958 %
# The area under curve is 0.3659479
# Warning message in if (class(model) %in% c("glm", "lm")) {:
# “the condition has length > 1 and only the first element will be used”
# The statistical significance for the model is 1
# The confidence level for the model is 0 %
# Plot with title “ROC Curve”

# %% [markdown]
# These numbers aren't as good. Hitherto, the model with SMOTE data has performed the best.

# %% [markdown]
# ### <a id=link10>5. Ratifying the *Pareto's Principle* </a>

# %% [markdown]
# The 80:20 rule is omnipresent in the domains of business and economy. Hardly would have the italian economist known at the time that his [theory](https://en.wikipedia.org/wiki/Pareto_principle) would be rooted deeper than his perception.

# %%
set.seed(6) # for reproducibility of results.
parts <- sample(2, nrow(k562greg),
               replace = TRUE,
               prob = c(0.8,0.2))
training <- k562greg[parts==1,]
testing <- k562greg[parts==2,]
cat("So, now we have", nrow(training), "training rows and", nrow(testing), "testing rows")
# Out:
# So, now we have 1215728 training rows and 303782 testing rows

# %%
k562paretoModel <- glm(formula = Class ~ ., data = training, family = "binomial")
summary(k562paretoModel)
# Out:
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Call:
# glm(formula = Class ~ ., family = "binomial", data = training)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -3.8111   0.0647   0.0659   0.0679   3.9498
#
# Coefficients:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept)  6.1680185  0.0225344 273.715  < 2e-16 ***
# CTCF         0.0030512  0.0091554   0.333  0.73894
# EP300       -0.0344865  0.0113765  -3.031  0.00243 **
# H3K27me3    -0.0534575  0.0207304  -2.579  0.00992 **
# H3K36me3    -0.0024049  0.0173100  -0.139  0.88950
# H3K4me1     -0.1003056  0.0092681 -10.823  < 2e-16 ***
# H3K4me2      0.0386521  0.0131651   2.936  0.00333 **
# H3K4me3     -0.0117776  0.0178403  -0.660  0.50915
# H3K9ac      -0.0369003  0.0072131  -5.116 3.13e-07 ***
# H3K9me3      0.0076770  0.0057463   1.336  0.18156
# RAD21        0.0807859  0.0178783   4.519 6.22e-06 ***
# RNA.Seq      0.0034119  0.0021310   1.601  0.10936
# RNAPol2     -0.0440874  0.0026431 -16.680  < 2e-16 ***
# RNAPol3     -0.0027557  0.0009284  -2.968  0.00299 **
# YY1          0.0226987  0.0132726   1.710  0.08723 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 41539  on 1215727  degrees of freedom
# Residual deviance: 40491  on 1215713  degrees of freedom
# AIC: 40521
#
# Number of Fisher Scoring iterations: 9

# %%
vif(k562paretoModel)
# Out:
#       CTCF      EP300   H3K27me3   H3K36me3    H3K4me1    H3K4me2    H3K4me3
#  36.447948   2.575689 139.866065  81.880890  12.183676  43.167724 125.022483
#     H3K9ac    H3K9me3      RAD21    RNA.Seq    RNAPol2    RNAPol3        YY1
#  22.777188   2.682299 268.177484   1.145475   2.911677   1.407280   1.834410

# %% [markdown]
# We observe that **CTCF**, **H3K36me3**, and **H3K4me3** have high values for *p* and variance inflation factor. Let's reorient the model omitting these values.

# %%
k562paretoModel1 <- glm(formula = Class ~ EP300 + H3K27me3 + H3K4me1 + H3K4me2 + H3K9ac + H3K9me3 + RAD21 + RNA.Seq + RNAPol2 + RNAPol3 + YY1, 
                        data = training, family = "binomial")
summary(k562paretoModel1)
# Out:
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Call:
# glm(formula = Class ~ EP300 + H3K27me3 + H3K4me1 + H3K4me2 +
#     H3K9ac + H3K9me3 + RAD21 + RNA.Seq + RNAPol2 + RNAPol3 +
#     YY1, family = "binomial", data = training)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -3.7869   0.0647   0.0659   0.0679   4.0238
#
# Coefficients:
#               Estimate Std. Error z value Pr(>|z|)
# (Intercept)  6.1675015  0.0222809 276.807  < 2e-16 ***
# EP300       -0.0328754  0.0111684  -2.944  0.00324 **
# H3K27me3    -0.0553798  0.0202692  -2.732  0.00629 **
# H3K4me1     -0.0991358  0.0080772 -12.273  < 2e-16 ***
# H3K4me2      0.0322728  0.0075925   4.251 2.13e-05 ***
# H3K9ac      -0.0394013  0.0064523  -6.107 1.02e-09 ***
# H3K9me3      0.0055938  0.0043788   1.277  0.20143
# RAD21        0.0788367  0.0132547   5.948 2.72e-09 ***
# RNA.Seq      0.0033823  0.0020641   1.639  0.10130
# RNAPol2     -0.0441930  0.0025690 -17.202  < 2e-16 ***
# RNAPol3     -0.0027912  0.0009204  -3.033  0.00242 **
# YY1          0.0236637  0.0132882   1.781  0.07494 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 41539  on 1215727  degrees of freedom
# Residual deviance: 40492  on 1215716  degrees of freedom
# AIC: 40516
#
# Number of Fisher Scoring iterations: 9

# %%
vif(k562paretoModel1)
# Out:
#      EP300   H3K27me3    H3K4me1    H3K4me2     H3K9ac    H3K9me3      RAD21
#   2.475093 132.773592   9.193897  14.295519  18.160081   1.595654 146.336104
#    RNA.Seq    RNAPol2    RNAPol3        YY1
#   1.077226   2.750659   1.391861   1.811487

# %%
modelPerformance(k562paretoModel1, testing, testing$Class)
# Out:
# The confusion matrix is
#          Actual
# Predicted      0      1
#         0      8      6
#         1    709 303059
# The misclassification error of the model is 0.2353662 %
# The sensitivity of the model is 1.11576 %
# The specificity of the model is 99.99802 %
# The area under curve is 0.5055689
# Warning message in if (class(model) %in% c("glm", "lm")) {:
# “the condition has length > 1 and only the first element will be used”
# The statistical significance for the model is 1
# The confidence level for the model is 0 %
# Plot with title “ROC Curve”

# %% [markdown]
# We see here that the issue of class imbalance imposes skewness on the classifier to predict solely non-hubs (represented by "1"). The balancing of the data, as practiced above, might come to the rescue. Let's examine the performance of the classifier on SMOTE transformed data.

# %% [markdown]
# #### <a id=link11>5.1 SMOTE data </a>

# %%
table(k562greg$Class)
# Out:
#       0       1
#    3677 1515833

# %%
training$Class <- as.factor(training$Class)
smoteDatum <- SMOTE(Class ~., training, perc.over = 10000, k = 5, perc.under = 100)
table(smoteDatum$Class)
# Out:
#      0      1
# 298960 296000

# %%
k562paretoModelSmote <- glm(formula = Class ~ ., data = smoteDatum, family = "binomial")
summary(k562paretoModelSmote)
# Out:
# Warning message:
# “glm.fit: fitted probabilities numerically 0 or 1 occurred”
# Call:
# glm(formula = Class ~ ., family = "binomial", data = smoteDatum)
#
# Deviance Residuals:
#    Min      1Q  Median      3Q     Max
# -1.833  -1.155  -0.061   1.028   8.490
#
# Coefficients:
#               Estimate Std. Error  z value Pr(>|z|)
# (Intercept)  0.9000617  0.0057234  157.259  < 2e-16 ***
# CTCF         0.0422972  0.0023847   17.737  < 2e-16 ***
# EP300        0.1364360  0.0041494   32.881  < 2e-16 ***
# H3K27me3    -0.4505331  0.0042382 -106.303  < 2e-16 ***
# H3K36me3    -0.2465598  0.0036652  -67.270  < 2e-16 ***
# H3K4me1     -0.2325712  0.0030033  -77.440  < 2e-16 ***
# H3K4me2      0.2226553  0.0051521   43.217  < 2e-16 ***
# H3K4me3     -0.1015624  0.0059206  -17.154  < 2e-16 ***
# H3K9ac      -0.1730488  0.0038290  -45.194  < 2e-16 ***
# H3K9me3     -0.0067479  0.0022772   -2.963  0.00304 **
# RAD21       -0.2213367  0.0066675  -33.197  < 2e-16 ***
# RNA.Seq      0.0101935  0.0005506   18.514  < 2e-16 ***
# RNAPol2     -0.0223245  0.0012716  -17.556  < 2e-16 ***
# RNAPol3     -0.0127430  0.0005573  -22.864  < 2e-16 ***
# YY1         -0.0096270  0.0047709   -2.018  0.04361 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 824775  on 594959  degrees of freedom
# Residual deviance: 753212  on 594945  degrees of freedom
# AIC: 753242
#
# Number of Fisher Scoring iterations: 7

# %%
modelPerformance(k562paretoModelSmote, testing, testing$Class)
# Out:
# The confusion matrix is
#          Actual
# Predicted      0      1
#         0    353  77420
#         1    364 225645
# The misclassification error of the model is 25.6052 %
# The sensitivity of the model is 49.23291 %
# The specificity of the model is 74.45432 %
# The area under curve is 0.6184362
# Warning message in if (class(model) %in% c("glm", "lm")) {:
# “the condition has length > 1 and only the first element will be used”
# The statistical significance for the model is 1
# The confidence level for the model is 0 %
# Plot with title “ROC Curve”

# %% [markdown]
# ### <a id=link12>6. Visualizing Predictions </a>

# %% [markdown]
# We choose to go with this model and will save the prediction results, that shall be later utilized for plotting.

# %%
k562gregModelPredictions <- predict(k562modelSMOTE, k562greg, type = "response")
k562gregModelPredictionsProbs <- ifelse(k562gregModelPredictions > 0.5, 1, 0)

# %% [markdown]
# Eventually, we have the original dataset with the classes and the one with the model predictions. We attempt to map the prediction results corresponding to LR-Hubs from the A549 cell-line. It will be interesting to see the intersect of the pre-caliberated LR-Hubs and the ones predicted by the classifier.
#
# <a href = "http://www.bioconductor.org/packages/release/bioc/html/Gviz.html" > Gviz </a> is the package we aim to deploy for visualization.

# %%
if(!requireNamespace("BiocManager", quietly = TRUE))
BiocManager::install("Gviz")
library(Gviz)
# Out:
# Loading required package: S4Vectors
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following object is masked from ‘package:Matrix’:
#
#     which
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     Filter, Find, Map, Position, Reduce, anyDuplicated, append,
#     as.data.frame, basename, cbind, colnames, dirname, do.call,
#     duplicated, eval, evalq, get, grep, grepl, intersect, is.unsorted,
#     lapply, mapply, match, mget, order, paste, pmax, pmax.int, pmin,
#     pmin.int, rank, rbind, rownames, sapply, setdiff, sort, table,
#     tapply, union, unique, unsplit, which, which.max, which.min
#
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:Matrix’:
#
#     expand
#
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
# Loading required package: IRanges
#
# Loading required package: GenomicRanges
#
# Loading required package: GenomeInfoDb

# %% [markdown]
# <p align="justify"> Next, we recall the data from the K562 cell-line (GREG). We already know, this is a comprehensive data (genome-wide) with values corresponding to epigenetic marks (features) for each bin (a 2Kb genomic region), in addition to a "Class", i.e. a "Hub" or a "Non-Hub". For the present case, we shall prune the data for the genomic intervals and their corresponding class. That is all we need! </p>

# %%
k562gregStandardRegionsClass <- k562gregStandard[, c(1:3,18)]

# %% [markdown]
# Also, considering the computational resources we deploy, we shall focus on chromosome 21 only.

# %%
# Extracting chr21 data

k562gregChr21NonHub <- k562gregStandardRegionsClass[k562gregStandardRegionsClass$chr=="chr21" & k562gregStandardRegionsClass$Class=="Non-Hub", ] ## subset of data for exemplifying
k562gregChr21Hub <- k562gregStandardRegionsClass[k562gregStandardRegionsClass$chr=="chr21" & k562gregStandardRegionsClass$Class=="Hub", ]

# %%
# Plotting Hubs

annotationTrackHub <- AnnotationTrack(range = k562gregChr21Hub, 
                                      name = "Hubs", 
                                      genome = "hg38", 
                                      chromosome = "chr21")
itrack <- IdeogramTrack(genome = "hg38", chromosome = "chr21")
genomeTrack <- GenomeAxisTrack()
plotTracks(list(annotationTrackHub, itrack, genomeTrack), 
           background.panel = "#FFFEDB", 
           background.title = "darkblue",
           stacking = "dense")
# Out:
# plot without title

# %% [markdown]
# So, there is a narrow occurrence of "hubs" in the chromosome 21, as seen above. The specific locations are given below.

# %%
# Plotting Non-Hubs

annotationTrackNonHub <- AnnotationTrack(range = k562gregChr21NonHub, 
                                         name = "Non-Hubs", 
                                         genome = "hg38", 
                                         chromosome = "chr21")
itrack <- IdeogramTrack(genome = "hg38", chromosome = "chr21")
plotTracks(list(annotationTrackNonHub, itrack),
           background.panel = "#FFFEDB", 
           background.title = "darkblue",
           stacking = "dense")
# Out:
# plot without title

# %% [markdown]
# We can observe that the Non-Hubs are pretty evenly distributed throughout the chromosome.In contrast, we are curious to examine if the findings of the classifier are able to fortify the original class definitions. Let us frame the data from the predicted results.

# %%
k562gregPredicted <- cbind(k562gregStandardRegionsClass, k562gregModelPredictionsProbs)
names(k562gregPredicted)[names(k562gregPredicted)=="k562gregModelPredictionsProbs"] <- "Prediction"
k562gregPredicted$Prediction <- ifelse(k562gregPredicted$Prediction == 1, "Non-Hub", "Hub")

# %% [markdown]
# Let us see if the classifier predictions match with the original results.

# %%
k562gregChr21PredicitedHub <- k562gregPredicted[k562gregPredicted$chr=="chr21" & k562gregPredicted$Prediction =="Hub", ]

# %% [markdown]
# Certainly, the predicted hubs are far more in number and there are noticeable instances of "Non-Hubs" that have been classified as "Hubs", with the given profile of the classification model.

# %%
# Plotting Predicted Hubs
annotationTrackHub <- AnnotationTrack(range = k562gregChr21Hub, 
                                      name = "Hubs", 
                                      genome = "hg38", 
                                      chromosome = "chr21")
annotationTrackPredictedHub <- AnnotationTrack(range = k562gregChr21PredicitedHub, 
                                               name = "Predicted Hubs", 
                                               genome = "hg38", 
                                               chromosome = "chr21")
itrack <- IdeogramTrack(genome = "hg38", chromosome = "chr21")
genomeTrack <- GenomeAxisTrack()
plotTracks(list(annotationTrackPredictedHub,annotationTrackHub, itrack, genomeTrack), 
           background.panel = "#FFFEDB", 
           background.title = "darkblue",
           stacking = "dense")
# Out:
# plot without title

# %%
truePositives <- k562gregPredicted[k562gregPredicted$Class == k562gregPredicted$Prediction, ]

# %% [markdown]
# As we close, we'll save the optimal model and true positive genomic regions (hubs) as explicit R data objects, in order to recall for later use.

# %%
save(k562modelSMOTE, file = "./optimalModels/k562modelLR")
write.table(truePositives, file = "./truePositives/k562LR.txt", quote = FALSE)

# %% [markdown]
# ### <a id=link13>7. Session Information </a>

# %%
sessionInfo()
# Out:
# R version 4.0.2 (2020-06-22)
# Platform: x86_64-apple-darwin17.0 (64-bit)
# Running under: macOS Catalina 10.15.6
#
# Matrix products: default
# BLAS:   /Library/Frameworks/R.framework/Versions/4.0/Resources/lib/libRblas.dylib
# LAPACK: /Library/Frameworks/R.framework/Versions/4.0/Resources/lib/libRlapack.dylib
#
# locale:
# [1] C/UTF-8/C/C/C/C
#
# attached base packages:
#  [1] parallel  stats4    grid      stats     graphics  grDevices utils
#  [8] datasets  methods   base
#
# other attached packages:
#  [1] Gviz_1.32.0          GenomicRanges_1.40.0 GenomeInfoDb_1.24.2
#  [4] IRanges_2.22.2       S4Vectors_0.26.1     BiocGenerics_0.34.0
#  [7] ROCR_1.0-11          DMwR_0.4.1           ROSE_0.0-3
# [10] e1071_1.7-3          caret_6.0-86         rms_6.0-1
# [13] SparseM_1.78         Hmisc_4.4-1          ggplot2_3.3.2
# [16] Formula_1.2-3        survival_3.2-3       lattice_0.20-41
# [19] glmnet_4.0-2         Matrix_1.2-18
#
# loaded via a namespace (and not attached):
#   [1] uuid_0.1-4                  backports_1.1.10
#   [3] BiocFileCache_1.12.1        plyr_1.8.6
#   [5] lazyeval_0.2.2              repr_1.1.0
#   [7] splines_4.0.2               BiocParallel_1.22.0
#   [9] TH.data_1.0-10              digest_0.6.25
#  [11] ensembldb_2.12.1            foreach_1.5.0
#  [13] htmltools_0.5.0             magrittr_1.5
#  [15] checkmate_2.0.0             memoise_1.1.0
#  [17] BSgenome_1.56.0             cluster_2.1.0
#  [19] recipes_0.1.13              Biostrings_2.56.0
#  [21] gower_0.2.2                 matrixStats_0.56.0
#  [23] xts_0.12.1                  sandwich_2.5-1
#  [25] askpass_1.1                 prettyunits_1.1.1
#  [27] jpeg_0.1-8.1                colorspace_1.4-1
#  [29] rappdirs_0.3.1              blob_1.2.1
#  [31] xfun_0.17                   dplyr_1.0.2
#  [33] crayon_1.3.4                RCurl_1.98-1.2
#  [35] jsonlite_1.7.1              VariantAnnotation_1.34.0
#  [37] zoo_1.8-8                   iterators_1.0.12
#  [39] glue_1.4.2                  gtable_0.3.0
#  [41] ipred_0.9-9                 zlibbioc_1.34.0
#  [43] XVector_0.28.0              MatrixModels_0.4-1
#  [45] DelayedArray_0.14.1         shape_1.4.5
#  [47] quantmod_0.4.17             abind_1.4-5
#  [49] scales_1.1.1                mvtnorm_1.1-1
#  [51] DBI_1.1.0                   Rcpp_1.0.5
#  [53] progress_1.2.2              htmlTable_2.1.0
#  [55] foreign_0.8-80              bit_4.0.4
#  [57] lava_1.6.7                  prodlim_2019.11.13
#  [59] htmlwidgets_1.5.1           httr_1.4.2
#  [61] RColorBrewer_1.1-2          ellipsis_0.3.1
#  [63] pkgconfig_2.0.3             XML_3.99-0.5
#  [65] nnet_7.3-14                 dbplyr_1.4.4
#  [67] tidyselect_1.1.0            rlang_0.4.7
#  [69] reshape2_1.4.4              AnnotationDbi_1.50.3
#  [71] munsell_0.5.0               tools_4.0.2
#  [73] generics_0.0.2              RSQLite_2.2.0
#  [75] evaluate_0.14               stringr_1.4.0
#  [77] ModelMetrics_1.2.2.2        knitr_1.29
#  [79] bit64_4.0.5                 purrr_0.3.4
#  [81] AnnotationFilter_1.12.0     nlme_3.1-149
#  [83] quantreg_5.67               biomaRt_2.44.1
#  [85] compiler_4.0.2              rstudioapi_0.11
#  [87] curl_4.3                    png_0.1-7
#  [89] tibble_3.0.3                stringi_1.5.3
#  [91] GenomicFeatures_1.40.1      IRdisplay_0.7.0
#  [93] ProtGenerics_1.20.0         vctrs_0.3.4
#  [95] pillar_1.4.6                lifecycle_0.2.0
#  [97] BiocManager_1.30.10         data.table_1.13.0
#  [99] bitops_1.0-6                conquer_1.0.2
# [101] rtracklayer_1.48.0          R6_2.4.1
# [103] latticeExtra_0.6-29         gridExtra_2.3
# [105] codetools_0.2-16            dichromat_2.0-0
# [107] polspline_1.1.19            assertthat_0.2.1
# [109] MASS_7.3-53                 SummarizedExperiment_1.18.2
# [111] openssl_1.4.3               withr_2.2.0
# [113] GenomicAlignments_1.24.0    Rsamtools_2.4.0
# [115] multcomp_1.4-13             GenomeInfoDbData_1.2.3
# [117] hms_0.5.3                   rpart_4.1-15
# [119] timeDate_3043.102           IRkernel_1.1.1
# [121] class_7.3-17                biovizBase_1.36.0
# [123] TTR_0.24.2                  pbdZMQ_0.3-3
# [125] pROC_1.16.2                 Biobase_2.48.0
# [127] lubridate_1.7.9             base64enc_0.1-3
